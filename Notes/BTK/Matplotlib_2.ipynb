# %% [markdown]
# ## next level plotting :|

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDizisi1 = np.linspace(0,10,20)
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2 = numpyDizisi1 ** 2
numpyDizisi2
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
(benimFigur, benimEksen) = plt.subplots()
benimEksen.plot(numpyDizisi1,numpyDizisi2,color ="#3A95A8",alpha = .3) # alpha for saydamlık
benimEksen.plot(numpyDizisi2, numpyDizisi1,color="#C96F23")
# rgb hex code

# %%
(yeniFigur, yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 2,color="blue",linewidth=8.0)
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 3,color="yellow")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 4,color="#C96F23",linestyle=":")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 5,color="#000000",linestyle="--",marker="o",markersize = 8,markerfacecolor="red")

# %% [markdown]
# # Farklı grafik çeşitleri

# %% [markdown]
# ### scatter

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)

# %% [markdown]
# ### histogram

# %%
yeniDizi = np.random.randint(0,100,50)
yeniDizi
# Out:
# array([57,  8, 45, 36,  1, 87, 98, 71, 65, 58, 83, 10, 76, 46, 36, 15, 31,
#        90, 91, 59, 57,  6, 80, 25,  7, 69, 38, 26, 40, 20, 21, 93, 29, 39,
#        82, 56, 32, 14, 10,  1, 18, 97, 86, 92, 70, 78, 40, 52, 18, 67])

# %%
plt.hist(yeniDizi)
# Out:
# (array([7., 5., 4., 6., 4., 6., 2., 5., 5., 6.]),
#  array([ 1. , 10.7, 20.4, 30.1, 39.8, 49.5, 59.2, 68.9, 78.6, 88.3, 98. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### boxplot

# %%
plt.boxplot(yeniDizi)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x235e543fb50>,
#   <matplotlib.lines.Line2D at 0x235e543fc70>],
#  'caps': [<matplotlib.lines.Line2D at 0x235e54146d0>,
#   <matplotlib.lines.Line2D at 0x235e5414b50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x235e543ffd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x235e54464c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x235e5446c10>],
#  'means': []}

# %%
plt.boxplot(yeniDizi*2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x235e51f5a60>,
#   <matplotlib.lines.Line2D at 0x235e53763a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x235e5458730>,
#   <matplotlib.lines.Line2D at 0x235e5458670>],
#  'boxes': [<matplotlib.lines.Line2D at 0x235e51f5ee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x235e5458e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x235e5458b20>],
#  'means': []}
